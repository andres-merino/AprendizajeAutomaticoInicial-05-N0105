# %% [markdown]
# <a href="https://colab.research.google.com/github/andres-merino/AprendizajeAutomaticoInicial-05-N0105/blob/main/2-Notebooks/05-1-Evaluacion-de-Modelos-Regresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="border: none; border-collapse: collapse;">
#     <tr>
#         <td style="width: 20%; vertical-align: middle; padding-right: 10px;">
#             <img src="https://i.imgur.com/nt7hloA.png" width="100">
#         </td>
#         <td style="width: 2px; text-align: center;">
#             <font color="#0030A1" size="7">|</font><br>
#             <font color="#0030A1" size="7">|</font>
#         </td>
#         <td>
#             <p style="font-variant: small-caps;"><font color="#0030A1" size="5">
#                 <b>Facultad de Ciencias Exactas, Naturales y Ambientales</b>
#             </font> </p>
#             <p style="font-variant: small-caps;"><font color="#0030A1" size="4">
#                 Aprendizaje Automático Inicial &bull; Evaluación de modelos - Regresión
#             </font></p>
#             <p style="font-style: oblique;"><font color="#0030A1" size="3">
#                 Andrés Merino &bull; Periodo 2025-02
#             </font></p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---
# ## <font color='264CC7'> Introducción </font>
#
# Este cuaderno está diseñado como una guía introductoria para la evaluación de modelos de aprendizaje automático. En él se presentan los conceptos básicos de evaluación de modelos, así como las métricas más comunes para evaluar la calidad de los modelos de regresión.

# %% [markdown]
# Los paquetes necesarios son:

# %%
# Paquetes necesarios
import numpy as np # Para manejo de arreglos
import pandas as pd  # Para manejo de datos estructurados
# Modelos de regresión
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ---
# ## <font color='264CC7'> Modelos de regresión </font>

# %% [markdown]
# Utilicemos datos ficticios:

# %%
# Datos simulados
np.random.seed(42)
X = np.random.rand(100) * 10 
y_true = 30 * X.squeeze() + 20
y_pred = 30 * X.squeeze() + np.random.randn(100) * 10 + 20

# Crear un DataFrame
df = pd.DataFrame({
    'X': X.squeeze(),
    'y_true': y_true,
    'y_pred': y_pred
})

# Mostrar los datos
display(df.head())
# Out:
#           X      y_true      y_pred
# 0  3.745401  132.362036  133.232506
# 1  9.507143  305.214292  302.224218
# 2  7.319939  239.598183  240.515790
# 3  5.986585  199.597545  179.721856
# 4  1.560186   66.805592   64.608873

# %% [markdown]
# Calculamos las métricas:

# %%
# Cálculo de métricas
mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
# Out:
# MAE: 7.21
# MSE: 82.51
# RMSE: 9.08

# %% [markdown]
# Reviso las estadísitca de los datos:

# %%
# Estadísitca de y_pred
print('Estadísticas de y_pred')
print(f'Media: {y_pred.mean():.2f}')
print(f'Mínimo: {y_pred.min():.2f}')
print(f'Máximo: {y_pred.max():.2f}')
# Out:
# Estadísticas de y_pred
# Media: 161.04
# Mínimo: 24.37
# Máximo: 323.88

# %% [markdown]
# ---
#
# <div style="background-color: #edf1f8; border-color: #264CC7; border-left: 5px solid #264CC7; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
# Multiplica los valores de y por un factor constante (por ejemplo, 10) y observa cómo cambian las métricas de evaluación. ¿Qué métricas son sensibles a la escala de los datos?
# </div>
#
# ---
